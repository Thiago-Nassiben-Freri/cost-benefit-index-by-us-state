# %% [markdown]
# ## Loading the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.stats import linregress


# Transform a csv file into a pandas dataframe
df = pd.read_csv("datasets\house_data.csv")

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724

# %%
df_2 = pd.read_csv("datasets\income_by_state.csv")

df_2
# Out:
#                    state  income_per_capita
# 0                Alabama              62212
# 1                 Alaska              86631
# 2                Arizona              77315
# 3               Arkansas              58700
# 4             California              95521
# 5               Colorado              92911
# 6            Connecticut              91665
# 7               Delaware              81361
# 8   District of Columbia             108210
# 9                Florida              73311
# 10               Georgia              74632
# 11                Hawaii              95322
# 12                 Idaho              74942
# 13              Illinois              80306
# 14               Indiana              69477
# 15                  Iowa              71433
# 16                Kansas              70333
# 17              Kentucky              61118
# 18             Louisiana              58229
# 19                 Maine              73733
# 20              Maryland              98678
# 21         Massachusetts              99858
# 22              Michigan              69183
# 23             Minnesota              85086
# 24           Mississippi              54203
# 25              Missouri              68545
# 26               Montana              70804
# 27              Nebraska              74590
# 28                Nevada              76364
# 29         New Hampshire              96838
# 30            New Jersey              99781
# 31            New Mexico              62268
# 32              New York              82095
# 33        North Carolina              70804
# 34          North Dakota              76525
# 35                  Ohio              67769
# 36              Oklahoma              62138
# 37                Oregon              80160
# 38          Pennsylvania              73824
# 39          Rhode Island              84972
# 40        South Carolina              67804
# 41          South Dakota              71810
# 42             Tennessee              67631
# 43                 Texas              75780
# 44                  Utah              93421
# 45               Vermont              81211
# 46              Virginia              89931
# 47            Washington              94605
# 48         West Virginia              55948
# 49             Wisconsin              74631
# 50               Wyoming              72415

# %%
df["income_per_capita"] = df_2["income_per_capita"]

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score  \
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724
#
#     income_per_capita
# 0               62212
# 1               86631
# 2               77315
# 3               58700
# 4               95521
# 5               92911
# 6               91665
# 7               81361
# 8              108210
# 9               73311
# 10              74632
# 11              95322
# 12              74942
# 13              80306
# 14              69477
# 15              71433
# 16              70333
# 17              61118
# 18              58229
# 19              73733
# 20              98678
# 21              99858
# 22              69183
# 23              85086
# 24              54203
# 25              68545
# 26              70804
# 27              74590
# 28              76364
# 29              96838
# 30              99781
# 31              62268
# 32              82095
# 33              70804
# 34              76525
# 35              67769
# 36              62138
# 37              80160
# 38              73824
# 39              84972
# 40              67804
# 41              71810
# 42              67631
# 43              75780
# 44              93421
# 45              81211
# 46              89931
# 47              94605
# 48              55948
# 49              74631
# 50              72415

# %%
df_3 = pd.read_csv("datasets\crime_rate_by_state.csv")

df_3
# Out:
#                    state  crime_rate_by_100k
# 0                Alabama               2.103
# 1                 Alaska               2.604
# 2                Arizona               2.206
# 3               Arkansas               2.849
# 4             California               2.834
# 5               Colorado               3.353
# 6            Connecticut               1.709
# 7               Delaware               2.261
# 8   District of Columbia               5.458
# 9                Florida               1.807
# 10               Georgia               2.175
# 11                Hawaii               1.857
# 12                 Idaho               1.044
# 13              Illinois               2.030
# 14               Indiana               1.875
# 15                  Iowa               1.721
# 16                Kansas               2.524
# 17              Kentucky               1.776
# 18             Louisiana               3.178
# 19                 Maine               1.223
# 20              Maryland               2.497
# 21         Massachusetts               1.415
# 22              Michigan               2.004
# 23             Minnesota               1.964
# 24           Mississippi               1.790
# 25              Missouri               2.554
# 26               Montana               2.276
# 27              Nebraska               2.206
# 28                Nevada               2.934
# 29         New Hampshire               0.996
# 30            New Jersey               1.743
# 31            New Mexico               3.637
# 32              New York               2.188
# 33        North Carolina               2.456
# 34          North Dakota               2.209
# 35                  Ohio               1.979
# 36              Oklahoma               2.562
# 37                Oregon               2.917
# 38          Pennsylvania               1.845
# 39          Rhode Island               1.289
# 40        South Carolina               2.664
# 41          South Dakota               1.968
# 42             Tennessee               2.990
# 43                 Texas               2.644
# 44                  Utah               1.864
# 45               Vermont               2.004
# 46              Virginia               1.895
# 47            Washington               3.244
# 48         West Virginia               1.461
# 49             Wisconsin               1.505
# 50               Wyoming               1.661

# %%
import numpy as np

df["crime_rate"] = df_3["crime_rate_by_100k"].astype(np.float64)

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score  \
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724
#
#     income_per_capita  crime_rate
# 0               62212       2.103
# 1               86631       2.604
# 2               77315       2.206
# 3               58700       2.849
# 4               95521       2.834
# 5               92911       3.353
# 6               91665       1.709
# 7               81361       2.261
# 8              108210       5.458
# 9               73311       1.807
# 10              74632       2.175
# 11              95322       1.857
# 12              74942       1.044
# 13              80306       2.030
# 14              69477       1.875
# 15              71433       1.721
# 16              70333       2.524
# 17              61118       1.776
# 18              58229       3.178
# 19              73733       1.223
# 20              98678       2.497
# 21              99858       1.415
# 22              69183       2.004
# 23              85086       1.964
# 24              54203       1.790
# 25              68545       2.554
# 26              70804       2.276
# 27              74590       2.206
# 28              76364       2.934
# 29              96838       0.996
# 30              99781       1.743
# 31              62268       3.637
# 32              82095       2.188
# 33              70804       2.456
# 34              76525       2.209
# 35              67769       1.979
# 36              62138       2.562
# 37              80160       2.917
# 38              73824       1.845
# 39              84972       1.289
# 40              67804       2.664
# 41              71810       1.968
# 42              67631       2.990
# 43              75780       2.644
# 44              93421       1.864
# 45              81211       2.004
# 46              89931       1.895
# 47              94605       3.244
# 48              55948       1.461
# 49              74631       1.505
# 50              72415       1.661

# %%
df_4 = pd.read_csv("datasets\life_exp.csv")

df_4
# Out:
#                    State  Mean
# 0                Alabama  72.0
# 1                 Alaska  74.5
# 2                Arizona  75.0
# 3               Arkansas  72.5
# 4             California  78.3
# 5               Colorado  77.7
# 6            Connecticut  79.2
# 7               Delaware  76.3
# 8   District of Columbia  75.3
# 9                Florida  76.1
# 10               Georgia  74.3
# 11                Hawaii  79.9
# 12                 Idaho  77.2
# 13              Illinois  77.1
# 14               Indiana  74.6
# 15                  Iowa  77.7
# 16                Kansas  76.0
# 17              Kentucky  72.3
# 18             Louisiana  72.2
# 19                 Maine  76.7
# 20              Maryland  77.2
# 21         Massachusetts  79.6
# 22              Michigan  75.7
# 23             Minnesota  78.8
# 24           Mississippi  70.9
# 25              Missouri  74.6
# 26               Montana  75.8
# 27              Nebraska  77.8
# 28                Nevada  75.1
# 29         New Hampshire  78.5
# 30            New Jersey  79.0
# 31            New Mexico  73.0
# 32              New York  79.0
# 33        North Carolina  74.9
# 34          North Dakota  77.6
# 35                  Ohio  74.5
# 36              Oklahoma  72.7
# 37                Oregon  77.4
# 38          Pennsylvania  76.4
# 39          Rhode Island  78.5
# 40        South Carolina  73.5
# 41          South Dakota  76.6
# 42             Tennessee  72.4
# 43                 Texas  75.4
# 44                  Utah  78.2
# 45               Vermont  78.4
# 46              Virginia  76.8
# 47            Washington  78.2
# 48         West Virginia  71.0
# 49             Wisconsin  77.8
# 50               Wyoming  75.0

# %%
df["life_expectancy"] = df_4["Mean"]

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score  \
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724
#
#     income_per_capita  crime_rate  life_expectancy
# 0               62212       2.103             72.0
# 1               86631       2.604             74.5
# 2               77315       2.206             75.0
# 3               58700       2.849             72.5
# 4               95521       2.834             78.3
# 5               92911       3.353             77.7
# 6               91665       1.709             79.2
# 7               81361       2.261             76.3
# 8              108210       5.458             75.3
# 9               73311       1.807             76.1
# 10              74632       2.175             74.3
# 11              95322       1.857             79.9
# 12              74942       1.044             77.2
# 13              80306       2.030             77.1
# 14              69477       1.875             74.6
# 15              71433       1.721             77.7
# 16              70333       2.524             76.0
# 17              61118       1.776             72.3
# 18              58229       3.178             72.2
# 19              73733       1.223             76.7
# 20              98678       2.497             77.2
# 21              99858       1.415             79.6
# 22              69183       2.004             75.7
# 23              85086       1.964             78.8
# 24              54203       1.790             70.9
# 25              68545       2.554             74.6
# 26              70804       2.276             75.8
# 27              74590       2.206             77.8
# 28              76364       2.934             75.1
# 29              96838       0.996             78.5
# 30              99781       1.743             79.0
# 31              62268       3.637             73.0
# 32              82095       2.188             79.0
# 33              70804       2.456             74.9
# 34              76525       2.209             77.6
# 35              67769       1.979             74.5
# 36              62138       2.562             72.7
# 37              80160       2.917             77.4
# 38              73824       1.845             76.4
# 39              84972       1.289             78.5
# 40              67804       2.664             73.5
# 41              71810       1.968             76.6
# 42              67631       2.990             72.4
# 43              75780       2.644             75.4
# 44              93421       1.864             78.2
# 45              81211       2.004             78.4
# 46              89931       1.895             76.8
# 47              94605       3.244             78.2
# 48              55948       1.461             71.0
# 49              74631       1.505             77.8
# 50              72415       1.661             75.0

# %%
df_5 = pd.read_csv("datasets/cost_living.csv")

df["cost_living_index"] = df_5["index_cost_living"]

# df = df.drop("cost_benefit_index", axis=1)

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score  \
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724
#
#     income_per_capita  crime_rate  life_expectancy  cost_living_index
# 0               62212       2.103             72.0               88.0
# 1               86631       2.604             74.5              123.8
# 2               77315       2.206             75.0              111.5
# 3               58700       2.849             72.5               88.7
# 4               95521       2.834             78.3              144.8
# 5               92911       3.353             77.7              102.0
# 6               91665       1.709             79.2              112.3
# 7               81361       2.261             76.3              100.8
# 8              108210       5.458             75.3              141.9
# 9               73311       1.807             76.1              102.8
# 10              74632       2.175             74.3               91.3
# 11              95322       1.857             79.9              186.9
# 12              74942       1.044             77.2              102.0
# 13              80306       2.030             77.1               94.4
# 14              69477       1.875             74.6               90.5
# 15              71433       1.721             77.7               89.7
# 16              70333       2.524             76.0               87.0
# 17              61118       1.776             72.3               93.0
# 18              58229       3.178             72.2               92.2
# 19              73733       1.223             76.7              112.1
# 20              98678       2.497             77.2              115.3
# 21              99858       1.415             79.6              145.9
# 22              69183       2.004             75.7               90.4
# 23              85086       1.964             78.8               95.1
# 24              54203       1.790             70.9               87.9
# 25              68545       2.554             74.6               88.7
# 26              70804       2.276             75.8               94.9
# 27              74590       2.206             77.8               93.1
# 28              76364       2.934             75.1              101.3
# 29              96838       0.996             78.5              112.6
# 30              99781       1.743             79.0              114.6
# 31              62268       3.637             73.0               93.3
# 32              82095       2.188             79.0              123.3
# 33              70804       2.456             74.9               97.8
# 34              76525       2.209             77.6               91.9
# 35              67769       1.979             74.5               94.2
# 36              62138       2.562             72.7               85.7
# 37              80160       2.917             77.4              112.0
# 38              73824       1.845             76.4               95.1
# 39              84972       1.289             78.5              112.2
# 40              67804       2.664             73.5               95.9
# 41              71810       1.968             76.6               92.2
# 42              67631       2.990             72.4               90.5
# 43              75780       2.644             75.4               92.7
# 44              93421       1.864             78.2              104.9
# 45              81211       2.004             78.4              114.4
# 46              89931       1.895             76.8              100.7
# 47              94605       3.244             78.2              114.2
# 48              55948       1.461             71.0               84.1
# 49              74631       1.505             77.8               97.0
# 50              72415       1.661             75.0               95.5

# %% [markdown]
# ## Descriptive Data Analysis

# %%
# Get the overall average home price in the United States 

average_house_price_us = df["median_home_value"].mean()
average_house_price_us = f"US$ {average_house_price_us:,.2f}"

print(average_house_price_us)
# Out:
# US$ 375,806.90

# %%
# Get the overall average outstanding mortgage balance in the United States

average_out_mortgage_balance = df["average_outstanding_mortgage_balance"].mean()
average_out_mortgage_balance_us = f"US$ {average_out_mortgage_balance:,.2f}"

print(average_out_mortgage_balance_us)
# Out:
# US$ 237,375.49

# %%
# Get the overall average fico score in the United States

average_fico_score = df["average_fico_score"].mean()
average_fico_score_us = f"{average_fico_score:.2f}"

print(average_fico_score_us)
# Out:
# 716.90

# %%
# Get the median value of house by state
states_house_price = df.groupby("state")["median_home_value"].max()
top_5 = states_house_price.nlargest(5) # Get the top five
i = 0

for state, val in top_5.items():
    print(f"{i + 1} - {state:<25} : US${val:,.2f}")
    i +=1
# Out:
# 1 - Hawaii                    : US$841,274.00
# 2 - California                : US$788,920.00
# 3 - Massachusetts             : US$635,252.00
# 4 - District of Columbia      : US$606,163.00
# 5 - Washington                : US$603,837.00

# %%
from matplotlib.ticker import StrMethodFormatter


# Figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Variables
state = top_5.index
house_val = top_5.values

# Ploting
plt.bar(state, house_val)

# Set a currency format in y-axis
ax.yaxis.set_major_formatter(StrMethodFormatter("${x:,.2f}"))

# Remove the borders
ax.spines[["top", "right"]].set_visible(False)

# Set a limit in y-axis
ax.set_ylim(0, 900000)

# Show
plt.show()

# %%
least_5 = states_house_price.nsmallest(5).sort_values(ascending=False)
j = len(df["state"]) - 5

for state, val in least_5.items():
    print(f"{j + 1} - {state:<25} : US${val:,.2f}")
    j += 1
# Out:
# 47 - Arkansas                  : US$210,633.00
# 48 - Oklahoma                  : US$208,281.00
# 49 - Louisiana                 : US$201,100.00
# 50 - Mississippi               : US$181,232.00
# 51 - West Virginia             : US$167,589.00

# %%
from matplotlib.ticker import StrMethodFormatter


# Figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Variables
state = least_5.index
house_val = least_5.values

# Ploting
plt.bar(state, house_val)

# Set a currency format in y-axis
ax.yaxis.set_major_formatter(StrMethodFormatter("${x:,.2f}"))

# Remove the borders
ax.spines[["top", "right"]].set_visible(False)

# Set a limit in y-axis
ax.set_ylim(0, 250000)

# Show
plt.show()

# %%
fico_score_by_state = df.groupby("state")["average_fico_score"].max()
top_5_fico = fico_score_by_state.nlargest(5)
y = 0

for state, fico in top_5_fico.items():
    print(f"{y + 1} - {state:<25} : {fico}/850")
    y += 1
# Out:
# 1 - Minnesota                 : 742/850
# 2 - Vermont                   : 738/850
# 3 - Wisconsin                 : 738/850
# 4 - New Hampshire             : 736/850
# 5 - Washington                : 735/850

# %%
least_5 = fico_score_by_state.nsmallest(5).sort_values(ascending=False)
z = len(df["state"]) - 5

for state, fico in least_5.items():
    print(f"{z + 1} - {state:<25} : {fico}/850")
    z += 1
# Out:
# 47 - Texas                     : 693/850
# 48 - Arkansas                  : 693/850
# 49 - Alabama                   : 690/850
# 50 - Louisiana                 : 688/850
# 51 - Mississippi               : 678/850

# %%
avg_income = df["income_per_capita"].mean()
avg_income = f"US$ {avg_income:,.2f}"

print(avg_income)
# Out:
# US$ 77,588.90

# %%
df[["income_per_capita", "median_home_value"]].corr()
# Out:
#                    income_per_capita  median_home_value
# income_per_capita           1.000000           0.820206
# median_home_value           0.820206           1.000000

# %%
income_by_state = df.groupby("state")["income_per_capita"].max()
top_income_by_state = income_by_state.nlargest(5)
a = 0

for state, income in top_income_by_state.items():
    print(f"{a + 1} - {state} : U${income:,.2f}")
    a += 1
# Out:
# 1 - District of Columbia : U$108,210.00
# 2 - Massachusetts : U$99,858.00
# 3 - New Jersey : U$99,781.00
# 4 - Maryland : U$98,678.00
# 5 - New Hampshire : U$96,838.00

# %%
least_income_by_state = income_by_state.nsmallest(5).sort_values(ascending=False)
b = len(income_by_state) - 5

for state, income in least_income_by_state.items():
    print(f"{b + 1} - {state} : U${income:,.2f}")
    b += 1
# Out:
# 47 - Kentucky : U$61,118.00
# 48 - Arkansas : U$58,700.00
# 49 - Louisiana : U$58,229.00
# 50 - West Virginia : U$55,948.00
# 51 - Mississippi : U$54,203.00

# %%
# Figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Variables
house_value = df["median_home_value"] / 1_000
income = df["income_per_capita"] / 1_000

# Calculate a linear regression
slope, intercept, r_value, p_value, std_err = linregress(income, house_value)
regression_line = slope * income + intercept

# Ploting 
plt.scatter(income, house_value)
plt.plot(income, regression_line, color='red')

# Axis labels
ax.set_ylabel("House Value", weight="bold", loc="top")
ax.set_xlabel("Income", weight="bold", loc="left")

# Limit of axis y and x
ax.set_ylim(100, 950)
ax.set_xlim(50, 120)

# Format the axis to "US$"
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'US$ {x:,.0f}K'))
ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'US$ {x:,.0f}K'))

# Remove the borders
ax.spines[["top", "right"]].set_visible(False)

# Show 
plt.show()

# %%
df[["median_home_value", "crime_rate"]].corr()
# Out:
#                    median_home_value  crime_rate
# median_home_value           1.000000    0.125612
# crime_rate                  0.125612    1.000000

# %% [markdown]
# ## Building the Index

# %%
# Normalizing index variables

norm_value = (df["median_home_value"].max() - df["median_home_value"]) / (df["median_home_value"].max() - df["median_home_value"].min())
norm_crime_rate = (df["crime_rate"].max() - df["crime_rate"]) / (df["crime_rate"].max() - df["crime_rate"].min())
norm_mortage = (df["average_outstanding_mortgage_balance"].max() - df["average_outstanding_mortgage_balance"]) / (df["average_outstanding_mortgage_balance"].max() - df["average_outstanding_mortgage_balance"].min())
norm_income = (df["income_per_capita"].max() - df["income_per_capita"]) / (df["income_per_capita"].max() - df["income_per_capita"].min())
norm_life_exp = (df["life_expectancy"].max() - df["life_expectancy"]) / (df["life_expectancy"].max() - df["life_expectancy"].min())
norm_cost_liv = (df["cost_living_index"].max() - df["cost_living_index"]) / (df["cost_living_index"].max() - df["cost_living_index"].min())

# %%
# The final index variable

cost_benefit_index = (norm_value * 0.16 + norm_crime_rate * 0.16 + norm_mortage * 0.16 + norm_income * 0.16 + norm_life_exp * 0.16 + norm_cost_liv * 0.16)

cost_benefit_index
# Out:
# 0     0.836667
# 1     0.576424
# 2     0.611211
# 3     0.820390
# 4     0.264201
# 5     0.430786
# 6     0.520433
# 7     0.622109
# 8     0.207655
# 9     0.648664
# 10    0.706510
# 11    0.208712
# 12    0.635096
# 13    0.666706
# 14    0.780361
# 15    0.730469
# 16    0.731298
# 17    0.851059
# 18    0.807019
# 19    0.674103
# 20    0.487428
# 21    0.368348
# 22    0.753753
# 23    0.602320
# 24    0.914867
# 25    0.752648
# 26    0.644209
# 27    0.678203
# 28    0.586487
# 29    0.539085
# 30    0.450577
# 31    0.729923
# 32    0.485922
# 33    0.692283
# 34    0.667578
# 35    0.781714
# 36    0.821392
# 37    0.510610
# 38    0.713401
# 39    0.564649
# 40    0.731900
# 41    0.699876
# 42    0.738393
# 43    0.664498
# 44    0.489044
# 45    0.592585
# 46    0.570987
# 47    0.384730
# 48    0.936378
# 49    0.688976
# 50    0.702007
# dtype: float64

# %%
# Adding the cost-benefit index to the Dataframe

df["cost_benefit_index"] = cost_benefit_index

df
# Out:
#                    state  median_home_value  \
# 0                Alabama             228669
# 1                 Alaska             371807
# 2                Arizona             429140
# 3               Arkansas             210633
# 4             California             788920
# 5               Colorado             551854
# 6            Connecticut             414183
# 7               Delaware             389974
# 8   District of Columbia             606163
# 9                Florida             387464
# 10               Georgia             329110
# 11                Hawaii             841274
# 12                 Idaho             462014
# 13              Illinois             273186
# 14               Indiana             244855
# 15                  Iowa             219987
# 16                Kansas             230884
# 17              Kentucky             217447
# 18             Louisiana             201100
# 19                 Maine             400642
# 20              Maryland             425692
# 21         Massachusetts             635252
# 22              Michigan             248560
# 23             Minnesota             337891
# 24           Mississippi             181232
# 25              Missouri             251663
# 26               Montana             459370
# 27              Nebraska             264859
# 28                Nevada             448322
# 29         New Hampshire             487482
# 30            New Jersey             548338
# 31            New Mexico             308031
# 32              New York             485932
# 33        North Carolina             331761
# 34          North Dakota             269509
# 35                  Ohio             234906
# 36              Oklahoma             208281
# 37                Oregon             500850
# 38          Pennsylvania             272299
# 39          Rhode Island             475865
# 40        South Carolina             298029
# 41          South Dakota             308842
# 42             Tennessee             319167
# 43                 Texas             303321
# 44                  Utah             530787
# 45               Vermont             388919
# 46              Virginia             400201
# 47            Washington             603837
# 48         West Virginia             167589
# 49             Wisconsin             312361
# 50               Wyoming             357698
#
#     average_outstanding_mortgage_balance  average_fico_score  \
# 0                                 182264                 690
# 1                                 266070                 722
# 2                                 274792                 711
# 3                                 168761                 693
# 4                                 449576                 722
# 5                                 346785                 730
# 6                                 260096                 726
# 7                                 223224                 712
# 8                                 510749                 714
# 9                                 257457                 706
# 10                                231225                 694
# 11                                413755                 731
# 12                                257644                 730
# 13                                200474                 721
# 14                                156496                 711
# 15                                160384                 729
# 16                                173204                 721
# 17                                159129                 704
# 18                                180754                 688
# 19                                177763                 731
# 20                                288500                 714
# 21                                322045                 731
# 22                                162525                 718
# 23                                214324                 742
# 24                                153515                 678
# 25                                173623                 712
# 26                                247187                 732
# 27                                178646                 730
# 28                                300511                 700
# 29                                227672                 736
# 30                                289863                 723
# 31                                197950                 702
# 32                                295426                 720
# 33                                217352                 708
# 34                                199973                 732
# 35                                152655                 714
# 36                                170580                 694
# 37                                289318                 731
# 38                                178705                 721
# 39                                233445                 720
# 40                                211894                 701
# 41                                195947                 733
# 42                                224239                 704
# 43                                245710                 693
# 44                                312174                 730
# 45                                178561                 738
# 46                                288102                 722
# 47                                357849                 735
# 48                                135930                 700
# 49                                171362                 738
# 50                                239965                 724
#
#     income_per_capita  crime_rate  life_expectancy  cost_living_index  \
# 0               62212       2.103             72.0               88.0
# 1               86631       2.604             74.5              123.8
# 2               77315       2.206             75.0              111.5
# 3               58700       2.849             72.5               88.7
# 4               95521       2.834             78.3              144.8
# 5               92911       3.353             77.7              102.0
# 6               91665       1.709             79.2              112.3
# 7               81361       2.261             76.3              100.8
# 8              108210       5.458             75.3              141.9
# 9               73311       1.807             76.1              102.8
# 10              74632       2.175             74.3               91.3
# 11              95322       1.857             79.9              186.9
# 12              74942       1.044             77.2              102.0
# 13              80306       2.030             77.1               94.4
# 14              69477       1.875             74.6               90.5
# 15              71433       1.721             77.7               89.7
# 16              70333       2.524             76.0               87.0
# 17              61118       1.776             72.3               93.0
# 18              58229       3.178             72.2               92.2
# 19              73733       1.223             76.7              112.1
# 20              98678       2.497             77.2              115.3
# 21              99858       1.415             79.6              145.9
# 22              69183       2.004             75.7               90.4
# 23              85086       1.964             78.8               95.1
# 24              54203       1.790             70.9               87.9
# 25              68545       2.554             74.6               88.7
# 26              70804       2.276             75.8               94.9
# 27              74590       2.206             77.8               93.1
# 28              76364       2.934             75.1              101.3
# 29              96838       0.996             78.5              112.6
# 30              99781       1.743             79.0              114.6
# 31              62268       3.637             73.0               93.3
# 32              82095       2.188             79.0              123.3
# 33              70804       2.456             74.9               97.8
# 34              76525       2.209             77.6               91.9
# 35              67769       1.979             74.5               94.2
# 36              62138       2.562             72.7               85.7
# 37              80160       2.917             77.4              112.0
# 38              73824       1.845             76.4               95.1
# 39              84972       1.289             78.5              112.2
# 40              67804       2.664             73.5               95.9
# 41              71810       1.968             76.6               92.2
# 42              67631       2.990             72.4               90.5
# 43              75780       2.644             75.4               92.7
# 44              93421       1.864             78.2              104.9
# 45              81211       2.004             78.4              114.4
# 46              89931       1.895             76.8              100.7
# 47              94605       3.244             78.2              114.2
# 48              55948       1.461             71.0               84.1
# 49              74631       1.505             77.8               97.0
# 50              72415       1.661             75.0               95.5
#
#     cost_benefit_index
# 0             0.836667
# 1             0.576424
# 2             0.611211
# 3             0.820390
# 4             0.264201
# 5             0.430786
# 6             0.520433
# 7             0.622109
# 8             0.207655
# 9             0.648664
# 10            0.706510
# 11            0.208712
# 12            0.635096
# 13            0.666706
# 14            0.780361
# 15            0.730469
# 16            0.731298
# 17            0.851059
# 18            0.807019
# 19            0.674103
# 20            0.487428
# 21            0.368348
# 22            0.753753
# 23            0.602320
# 24            0.914867
# 25            0.752648
# 26            0.644209
# 27            0.678203
# 28            0.586487
# 29            0.539085
# 30            0.450577
# 31            0.729923
# 32            0.485922
# 33            0.692283
# 34            0.667578
# 35            0.781714
# 36            0.821392
# 37            0.510610
# 38            0.713401
# 39            0.564649
# 40            0.731900
# 41            0.699876
# 42            0.738393
# 43            0.664498
# 44            0.489044
# 45            0.592585
# 46            0.570987
# 47            0.384730
# 48            0.936378
# 49            0.688976
# 50            0.702007

# %%
cost_benefit_idx_state = df.groupby("state")["cost_benefit_index"].max()
top_cost_benefit_idx_state = cost_benefit_idx_state.nlargest(5)
a = 0

for state, index in top_cost_benefit_idx_state.items():
    print(f"{a + 1} - {state} : {index:,.2f}/1")
    a += 1
# Out:
# 1 - West Virginia : 0.94/1
# 2 - Mississippi : 0.91/1
# 3 - Kentucky : 0.85/1
# 4 - Alabama : 0.84/1
# 5 - Oklahoma : 0.82/1

# %%
cost_benefit_idx_state = df.groupby("state")["cost_benefit_index"].min()
least_cost_benefit_idx_state = cost_benefit_idx_state.nsmallest(5).sort_values(ascending=False)
a = 46

for state, income in least_cost_benefit_idx_state.items():
    print(f"{a + 1} - {state} : {income:,.2f}/1")
    a += 1
# Out:
# 47 - Washington : 0.38/1
# 48 - Massachusetts : 0.37/1
# 49 - California : 0.26/1
# 50 - Hawaii : 0.21/1
# 51 - District of Columbia : 0.21/1

# %% [markdown]
# ## Results
#
# After calculating the "Cost Benefit" Index, we obtain the results:
#
# *States with the Highest Cost-Benefit*: West Virginia, Mississippi, Kentucky, Alabama and Arkansas.
#
# *States with the Lowest Cost-Benefit*: Massachusetts, Washington, California, District of Columbia and Hawaii.
#
# Warning: States considered poorer may be biased to have higher scores, as the weights may "benefit" their lack of wealth.
